# %%
import trimesh
import numpy as np

p = "/home/jonas/catkin_ws/src/Kimera-Interfacer/kimera_interfacer/mesh_results/mesh.ply"
res = trimesh.exchange.load.load( p )

# with open(p) as f:
#     res2 = trimesh.exchange.ply.load_ply(f)

# %%
dir( res )
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_cache',
#  '_center_mass',
#  '_data',
#  '_density',
#  '_kwargs',
#  '_visual',
#  'apply_obb',
#  'apply_scale',
#  'apply_transform',
#  'apply_translation',
#  'area',
#  'area_faces',
#  'as_open3d',
#  'body_count',
#  'bounding_box',
#  'bounding_box_oriented',
#  'bounding_cylinder',
#  'bounding_primitive',
#  'bounding_sphere',
#  'bounds',
#  'center_mass',
#  'centroid',
#  'compute_stable_poses',
#  'contains',
#  'convert_units',
#  'convex_decomposition',
#  'convex_hull',
#  'copy',
#  'crc',
#  'density',
#  'difference',
#  'edges',
#  'edges_face',
#  'edges_sorted',
#  'edges_sorted_tree',
#  'edges_sparse',
#  'edges_unique',
#  'edges_unique_inverse',
#  'edges_unique_length',
#  'euler_number',
#  'eval_cached',
#  'export',
#  'extents',
#  'face_adjacency',
#  'face_adjacency_angles',
#  'face_adjacency_convex',
#  'face_adjacency_edges',
#  'face_adjacency_edges_tree',
#  'face_adjacency_projections',
#  'face_adjacency_radius',
#  'face_adjacency_span',
#  'face_adjacency_tree',
#  'face_adjacency_unshared',
#  'face_angles',
#  'face_angles_sparse',
#  'face_attributes',
#  'face_normals',
#  'faces',
#  'faces_sparse',
#  'faces_unique_edges',
#  'facets',
#  'facets_area',
#  'facets_boundary',
#  'facets_normal',
#  'facets_on_hull',
#  'facets_origin',
#  'fill_holes',
#  'fix_normals',
#  'identifier',
#  'identifier_md5',
#  'intersection',
#  'invert',
#  'is_convex',
#  'is_empty',
#  'is_volume',
#  'is_watertight',
#  'is_winding_consistent',
#  'kdtree',
#  'mass',
#  'mass_properties',
#  'md5',
#  'merge_vertices',
#  'metadata',
#  'moment_inertia',
#  'nearest',
#  'outline',
#  'permutate',
#  'principal_inertia_components',
#  'principal_inertia_transform',
#  'principal_inertia_vectors',
#  'process',
#  'ray',
#  'referenced_vertices',
#  'register',
#  'remove_degenerate_faces',
#  'remove_duplicate_faces',
#  'remove_infinite_values',
#  'remove_unreferenced_vertices',
#  'rezero',
#  'sample',
#  'scale',
#  'scene',
#  'section',
#  'section_multiplane',
#  'show',
#  'simplify_quadratic_decimation',
#  'slice_plane',
#  'smoothed',
#  'split',
#  'subdivide',
#  'submesh',
#  'symmetry',
#  'symmetry_axis',
#  'symmetry_section',
#  'to_dict',
#  'triangles',
#  'triangles_center',
#  'triangles_cross',
#  'triangles_tree',
#  'union',
#  'units',
#  'unmerge_vertices',
#  'unwrap',
#  'update_faces',
#  'update_vertices',
#  'vertex_adjacency_graph',
#  'vertex_attributes',
#  'vertex_defects',
#  'vertex_degree',
#  'vertex_faces',
#  'vertex_neighbors',
#  'vertex_normals',
#  'vertices',
#  'visual',
#  'volume',
#  'voxelized']

# %%
out = res.as_open3d

# %%
out.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f4614d612f96> in <module>
# ----> 1 out.dtype
#
# AttributeError: 'open3d.cuda.pybind.geometry.TriangleMesh' object has no attribute 'dtype'

# %%
import open3d as o3d
import numpy as np
from open3d.visualization import Visualizer
points = (np.random.rand(1000, 3) - 0.5) / 4
colors = np.random.rand(1000, 3)

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
pcd.colors = o3d.utility.Vector3dVector(colors)

# visualizer = Visualizer()
# visualizer.add_geometry(pcd)
# visualizer.create_window()
# visualizer.run()
# visualizer.update_geometry()

# %%
# examples/python/visualization/non_blocking_visualization.py

import open3d as o3d
import numpy as np
import copy

if __name__ == "__main__":
    o3d.utility.set_verbosity_level(o3d.utility.VerbosityLevel.Debug)
                                    
    vis = o3d.visualization.Visualizer()
    vis.create_window()
    vis.add_geometry(pcd)
    threshold = 0.05
    icp_iteration = 100
    save_image = False

    for i in range(icp_iteration):
        reg_p2l = o3d.pipelines.registration.registration_icp(
            source, target, threshold, np.identity(4),
            o3d.pipelines.registration.TransformationEstimationPointToPlane(),
            o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=1))
        source.transform(reg_p2l.transformation)
        vis.poll_events()
        vis.update_renderer()
        if save_image:
            vis.capture_screen_image("temp_%04d.jpg" % i)
    vis.destroy_window()
# Out:
# [Open3D DEBUG] GLFW init.
# [Open3D DEBUG] Add geometry and update bounding box to [(-0.1247, -0.1248, -0.1250) - (0.1249, 0.1250, 0.1246)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ed676950c6e1> in <module>
#      17     for i in range(icp_iteration):
#      18         reg_p2l = o3d.pipelines.registration.registration_icp(
# ---> 19             source, target, threshold, np.identity(4),
#      20             o3d.pipelines.registration.TransformationEstimationPointToPlane(),
#      21             o3d.pipelines.registration.ICPConvergenceCriteria(max_iteration=1))
#
# NameError: name 'source' is not defined
